# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
## define important constants
mass_vol = 1 # g/cm^3
dists = np.array([5,20]) # distance a considérer
attenuation = 2.102E-02 # cm^2/g
mu = attenuation * mass_vol # 1/cm
fracSig = np.exp(-mu * dists)

# %%
fracSig
# Out:
# array([0.90023449, 0.65678405])

# %%
passw = np.loadtxt("PythonFiles/data/sinogram-password.txt")
patient = np.loadtxt("PythonFiles/data/sinogram-patient.txt")

# %%
plt.imshow(passw)

# %%
plt.imshow(patient)
passw.shape
# Out:
# (720, 336)

# %%
from PythonFiles.CTfilter import filterSinogram
from PythonFiles.recon import backproject
backproject()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from PythonFiles.CTfilter import filterSinogram
#       2 from PythonFiles.recon import backproject
#       3 backproject()
#
# File c:\Users\micha\OneDrive\Documents\GitHub\TP_PhysNum\TP2\PythonFiles\CTfilter.py:10
#       1 #!/usr/bin/env python
#       2 # -*- coding: utf-8 -*-
#       3 # TP reconstruction TDM (CT)
#    (...)      7
#       8 # libs
#       9 import numpy as np
# ---> 10 from scipy.fft import fft, ifft, fftfreq
#      11 ## filtrer le sinogramme
#      12 ## ligne par ligne
#      14 def filterSinogram(sinogram):
#
# File c:\Users\micha\AppData\Local\Programs\Python\Python312-arm64\Lib\site-packages\scipy\fft\__init__.py:91
#      86 from ._basic import (
#      87     fft, ifft, fft2, ifft2, fftn, ifftn,
#      88     rfft, irfft, rfft2, irfft2, rfftn, irfftn,
#      89     hfft, ihfft, hfft2, ihfft2, hfftn, ihfftn)
#      90 from ._realtransforms import dct, idct, dst, idst, dctn, idctn, dstn, idstn
# ---> 91 from ._fftlog import fht, ifht, fhtoffset
#      92 from ._helper import (
#      93     next_fast_len, prev_fast_len, fftfreq,
#      94     rfftfreq, fftshift, ifftshift)
#      95 from ._backend import (set_backend, skip_backend, set_global_backend,
#      96                        register_backend)
#
# File c:\Users\micha\AppData\Local\Programs\Python\Python312-arm64\Lib\site-packages\scipy\fft\_fftlog.py:10
#       8 from ._basic import _dispatch
#       9 from scipy._lib.uarray import Dispatchable
# ---> 10 from ._fftlog_backend import fhtoffset
#      11 import numpy as np
#      13 __all__ = ['fht', 'ifht', 'fhtoffset']
#
# File c:\Users\micha\AppData\Local\Programs\Python\Python312-arm64\Lib\site-packages\scipy\fft\_fftlog_backend.py:4
#       2 from warnings import warn
#       3 from ._basic import rfft, irfft
# ----> 4 from ..special import loggamma, poch
#       6 from scipy._lib._array_api import array_namespace, copy
#       8 __all__ = ['fht', 'ifht', 'fhtoffset']
#
# File c:\Users\micha\AppData\Local\Programs\Python\Python312-arm64\Lib\site-packages\scipy\special\__init__.py:815
#     810 # Replace some function definitions from _ufuncs to add Array API support
#     811 from ._support_alternative_backends import (
#     812     log_ndtr, ndtr, ndtri, erf, erfc, i0, i0e, i1, i1e, gammaln,
#     813     gammainc, gammaincc, logit, expit, entr, rel_entr, xlogy, chdtrc)
# --> 815 from . import _basic
#     816 from ._basic import *
#     818 from ._logsumexp import logsumexp, softmax, log_softmax
#
# File c:\Users\micha\AppData\Local\Programs\Python\Python312-arm64\Lib\site-packages\scipy\special\_basic.py:19
#      14 from ._ufuncs import (mathieu_a, mathieu_b, iv, jv, gamma,
#      15                       psi, hankel1, hankel2, yv, kv, poch, binom,
#      16                       _stirling2_inexact)
#      17 from ._gufuncs import (_lpn, _lpmn, _clpmn, _lqn, _lqmn, _rctj, _rcty,
#      18                        _sph_harm_all as _sph_harm_all_gufunc)
# ---> 19 from . import _specfun
#      20 from ._comb import _comb_int
#      23 __all__ = [
#      24     'ai_zeros',
#      25     'assoc_laguerre',
#    (...)     82     'zeta'
#      83 ]
#
# File <frozen importlib._bootstrap>:645, in parent(self)
#
# KeyboardInterrupt:

# %%
#res = filterSinogram(passw)

# %%
#res = fft2(passw).real
plt.imshow(res)
